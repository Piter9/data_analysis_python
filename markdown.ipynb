# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** Fathir Maula. S
# - **Email:** fathirmaula89@gmail.com
# - **ID Dicoding:** piter999

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Kapan kondisi rata-rata suhu bulanan ke 12 station mencapai batas maksimum dan minimum dalam kurun 2013-2017 ?
# - Bagaimana perkembangan suhu bulanan di wilayah Dongsi pada bulan tahun 2014 ?
# - Apakah ada hubungan antara suhu dan kadar O3, NO2, SO2 di udara?
# - Dimana wilayah dengan polutan udara (PM2.5, PM10, SO2, NO2, O3) terbanyak tahun 2014? (tambahan)

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Data 1 Air Quality Aotizhoxin
aq_aotizhongxin_df = pd.read_csv('data/PRSA_Data_Aotizhongxin_20130301-20170228.csv')
aq_aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
# Data 2 Air Quality Changping
aq_changping_df = pd.read_csv('data/PRSA_Data_Changping_20130301-20170228.csv')
aq_changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
# Data 3 Air Quality Dingling
aq_dingling_df = pd.read_csv('data/PRSA_Data_Dingling_20130301-20170228.csv')
aq_dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
# Data 4 Air Quality Dongsi
aq_dongsi_df = pd.read_csv('data/PRSA_Data_Dongsi_20130301-20170228.csv')
aq_dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
# Data 5 Air Quality Guanyuan
aq_guanyuan_df = pd.read_csv('data/PRSA_Data_Guanyuan_20130301-20170228.csv')
aq_guanyuan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
# Data 6 Air Quality Gucheng
aq_gucheng_df = pd.read_csv('data/PRSA_Data_Gucheng_20130301-20170228.csv')
aq_gucheng_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %%
# Data 7 Air Quality Huairou
aq_huairou_df = pd.read_csv('data/PRSA_Data_Huairou_20130301-20170228.csv')
aq_huairou_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
# Data 8 Air Quality Nongzhanguan
aq_nongzhanguan_df = pd.read_csv('data/PRSA_Data_Nongzhanguan_20130301-20170228.csv')
aq_nongzhanguan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
# Data 9 Air Quality Shunyi
aq_shunyi_df = pd.read_csv('data/PRSA_Data_Shunyi_20130301-20170228.csv')
aq_shunyi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
# Data 10 Air Quality Tiantan
aq_tiantan_df = pd.read_csv('data/PRSA_Data_Tiantan_20130301-20170228.csv')
aq_tiantan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %%
# Data 11 Air Quality Wanliu
aq_wanliu_df = pd.read_csv('data/PRSA_Data_Wanliu_20130301-20170228.csv')
aq_wanliu_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %%
# Data 12 Air Quality Wanshouxigong
aq_wanshouxigong_df = pd.read_csv('data/PRSA_Data_Wanshouxigong_20130301-20170228.csv')
aq_wanshouxigong_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# **Insight:**
# - Terdapat 12 tabel yang berisikan data kualitas udara di 12 daerah di Negara RRT yang berbeda.
# - Semua tabel memiliki kolom yang sama dan periode waktu yang sama
#
# </br>Sehingga, dapat disimpulkan **semua tabel dapat digabungkan menjadi satu** dengan waktu sebagai reference key demi mempermudah proses analisis

# %%
# Menggabungkan 12 tabel tersebut

## Inisisi file gabungan
nama_files = [
                aq_aotizhongxin_df, aq_changping_df, aq_dingling_df,
                aq_dongsi_df, aq_wanshouxigong_df, aq_guanyuan_df,
                aq_gucheng_df, aq_huairou_df, aq_nongzhanguan_df,
                aq_shunyi_df, aq_tiantan_df, aq_wanliu_df,
             ]
df_merged = pd.concat(nama_files, ignore_index = True)
df_merged
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1           2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2           3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3           4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4           5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 420763  35060  2017      2   28    19   11.0  27.0   4.0  20.0  300.0  81.0
# 420764  35061  2017      2   28    20   15.0  43.0   6.0  55.0  500.0  45.0
# 420765  35062  2017      2   28    21   13.0  35.0   7.0  48.0  500.0  48.0
# 420766  35063  2017      2   28    22   12.0  31.0   5.0  47.0  500.0  50.0
# 420767  35064  2017      2   28    23    7.0  25.0   6.0  86.0  700.0  11.0
#
# ...

# %% [markdown]
# Setelah dilakukan penggabungan, di dapatkan 1 tabel yang siap untuk dilakukan Assesing Data

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Overview Data (Deskriptif)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       420768 non-null  int64
#  1   year     420768 non-null  int64
#  2   month    420768 non-null  int64
#  3   day      420768 non-null  int64
#  4   hour     420768 non-null  int64
#  5   PM2.5    412029 non-null  float64
#  6   PM10     414319 non-null  float64
#  7   SO2      411747 non-null  float64
#  8   NO2      408652 non-null  float64
#  9   CO       400067 non-null  float64
#  10  O3       407491 non-null  float64
#  11  TEMP     420370 non-null  float64
#  12  PRES     420375 non-null  float64
#  13  DEWP     420365 non-null  float64
#  14  RAIN     420378 non-null  float64
#  15  wd       418946 non-null  object
#  16  WSPM     420450 non-null  float64
#  17  station  420768 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 57.8+ MB

# %% [markdown]
# **Insight :**
# - Terdapat 18 kolom dan 420.768 baris data
# - Terdapat perbedaan jumlah baris bukan null, sehingga terdapat **indikasi null value**
# - Semua tipe data sudah sesuai, **tapi**, bisa saja tipe yang berjenis waktu di gabung menjadi tipe DateTime (tergantung kebutuhan analisis)

# %%
df_merged.describe(include='all')
# Out:
#                    No           year          month            day  \
# count   420768.000000  420768.000000  420768.000000  420768.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean     17532.500000    2014.662560       6.522930      15.729637
# std      10122.116943       1.177198       3.448707       8.800102
# min          1.000000    2013.000000       1.000000       1.000000
# 25%       8766.750000    2014.000000       4.000000       8.000000
# 50%      17532.500000    2015.000000       7.000000      16.000000
# 75%      26298.250000    2016.000000      10.000000      23.000000
# max      35064.000000    2017.000000      12.000000      31.000000
#
#                  hour          PM2.5           PM10            SO2  \
# count   420768.000000  420768.000000  420768.000000  420768.000000
# ...

# %% [markdown]
# **Insight:**
# - Terdapat beberapa kolom yang memiliki nilai max yang sangat jauh dari rata-ratanya (**perlu di cek indikasi outlier**)

# %% [markdown]
# #### Missing dan Duplikat Values

# %%
## Cek Missing Values

df_merged.isnull().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5       8739
# PM10        6449
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# dtype: int64

# %%
# cek data duplikat

df_merged.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - Terdapat 12 Kolom yang memiliki missing values
# - Tidak ada data duplikat

# %% [markdown]
# #### Cek Outlier

# %%
for column in df_merged.select_dtypes(include=['float64']).columns:
    Q1 = df_merged[column].quantile(0.25)
    Q3 = df_merged[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    print(f"batas bawah untuk {column}: {lower_bound}")
    print(f"batas atas untuk {column}: {upper_bound}")
# Out:
# batas bawah untuk PM2.5: -116.5
# batas atas untuk PM2.5: 247.5
# batas bawah untuk PM10: -127.5
# batas atas untuk PM10: 308.5
# batas bawah untuk SO2: -22.5
# batas atas untuk SO2: 45.5
# batas bawah untuk NO2: -49.0
# batas atas untuk NO2: 143.0
# batas bawah untuk CO: -1000.0
# batas atas untuk CO: 3000.0
# batas bawah untuk O3: -98.0
# batas atas untuk O3: 190.0
# batas bawah untuk TEMP: -27.199999999999996
# batas atas untuk TEMP: 53.599999999999994
# batas bawah untuk PRES: 977.2499999999999
# batas atas untuk PRES: 1044.0500000000002
# batas bawah untuk DEWP: -44.9
# batas atas untuk DEWP: 51.1
# batas bawah untuk RAIN: 0.0
# batas atas untuk RAIN: 0.0
# batas bawah untuk WSPM: -1.0500000000000003
# batas atas untuk WSPM: 4.15

# %% [markdown]
# **Insight :**
# Setelah di bandingkan temuan diatas dan teorinya, terdapat indikasi ketidak wajaran pada kolom 6 - 11 atau (PM2.5 - O3)

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Handling Missing Values

# %% [markdown]
# Karena datanya berbentuk series waktu, maka handling missing values menggunakan intrpolasi suapay tidak banyak informasi yang hilang

# %%
df_merged.interpolate(method="linear", limit_direction="forward", inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9204\2923446866.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_merged.interpolate(method="linear", limit_direction="forward", inplace=True)

# %%
df_merged.isnull().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5         0
# PM10          0
# SO2           0
# NO2           0
# CO            0
# O3            0
# TEMP          0
# PRES          0
# DEWP          0
# RAIN          0
# wd         1822
# WSPM          0
# station       0
# dtype: int64

# %% [markdown]
# Missing values tersisa pada wind direction, untuk mengatasinya saya memilih untuk mengisinya dengan isian satu baris sebelumnya dengan asumsi arah angin berubah tidak terlalu berbeda pada jam sebelumnya

# %%
df_merged.fillna(method="ffill", inplace=True)
df_merged.isnull().sum()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9204\2561294748.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_merged.fillna(method="ffill", inplace=True)
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# **Kesimpulan:**
# Missing value sudah ditangani

# %% [markdown]
# #### Handling Outlier

# %%
kolom_outliers = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']
batas_atas = [200, 200, 100, 100, 3000, 200]

for kolom,kondisi in zip(kolom_outliers,batas_atas) :
    pengganti = df_merged[kolom]/10
    df_merged[kolom].mask(cond= df_merged[kolom] >= kondisi, other = df_merged[kolom]/10, inplace=True)

df_merged.describe()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9204\1373543055.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_merged[kolom].mask(cond= df_merged[kolom] >= kondisi, other = df_merged[kolom]/10, inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9204\1373543055.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# Data sudah menjadi lebih masuk akal, lanjut ke tahapan EDA

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore By Station

# %%
df_merged.groupby("station").agg({
    "TEMP" : ['max', 'min', 'mean'],
})
# Out:
#                TEMP
#                 max   min       mean
# station
# Aotizhongxin   40.5 -16.8  13.581414
# Changping      41.4 -16.6  13.671605
# Dingling       41.4 -16.6  13.671605
# Dongsi         41.1 -16.8  13.668250
# Guanyuan       40.5 -16.8  13.581414
# Gucheng        41.6 -15.6  13.855824
# Huairou        40.3 -19.9  12.430556
# Nongzhanguan   41.1 -16.8  13.668250
# Shunyi         40.6 -16.8  13.375531
# Tiantan        41.1 -16.8  13.668250
# Wanliu         40.5 -15.8  13.425795
# Wanshouxigong  40.6 -16.8  13.781808

# %%
df_merged.groupby("station").agg({
    "PM2.5" : 'mean',
    "PM10" : 'mean',
    "SO2" : 'mean',
    "NO2" : 'mean',
    "CO" : 'mean',
    "O3" : 'mean',
})
# Out:
#                    PM2.5       PM10        SO2        NO2           CO  \
# station
# Aotizhongxin   60.193907  72.199625  15.780740  43.143647   926.951261
# Changping      54.692313  68.894299  13.686789  38.125550   892.899463
# Dingling       51.305733  62.999862  11.522979  24.901491   790.270360
# Dongsi         60.455077  71.762322  16.841742  42.007490  1014.057904
# Guanyuan       60.977350  74.191392  15.840364  43.724011   953.771058
# Gucheng        61.003288  76.303462  14.395762  42.070475   973.339206
# Huairou        54.679403  66.255763  11.529430  29.570204   894.217685
# Nongzhanguan   59.456721  71.614955  16.660722  42.736213   967.170366
# Shunyi         58.194394  68.768728  12.629685  37.634213   920.632157
# Tiantan        60.135720  73.647119  13.360132  43.193707   985.626948
# Wanliu         60.580228  73.454322  16.835093  45.628160   945.561008
# Wanshouxigong  60.434551  73.279570  15.390283  41.938691  1010.346674
#
#                       O3
# ...

# %% [markdown]
# ### Explore By Time

# %%
quest_1 = df_merged.groupby(["year", "month"]).agg(
    max =('TEMP','max'),
    min = ('TEMP','min'),
    mean = ('TEMP','mean')
).reset_index()
quest_1['month_year'] = quest_1['month'].astype(str).str.zfill(2) + '-' + quest_1['year'].astype(str).str.zfill(2)

quest_1
# Out:
#     year  month   max     min       mean month_year
# 0   2013      3  22.9  -7.200   5.992249    03-2013
# 1   2013      4  29.4  -1.600  12.380058    04-2013
# 2   2013      5  35.4   7.800  21.676691    05-2013
# 3   2013      6  35.7  13.100  23.583426    06-2013
# 4   2013      7  38.0  18.100  27.108826    07-2013
# 5   2013      8  37.7  12.900  26.904620    08-2013
# 6   2013      9  31.8   6.100  20.240683    09-2013
# 7   2013     10  26.4  -0.200  12.984017    10-2013
# 8   2013     11  18.9  -9.700   5.963900    11-2013
# 9   2013     12  15.4 -11.600   0.054167    12-2013
# 10  2014      1  13.4 -14.300  -0.283031    01-2014
# 11  2014      2   9.9 -14.500  -0.346850    02-2014
# 12  2014      3  26.2  -7.300   9.901467    03-2014
# 13  2014      4  30.6   2.700  17.017998    04-2014
# 14  2014      5  41.6   4.300  21.616420    05-2014
# 15  2014      6  37.5  13.200  24.766296    06-2014
# 16  2014      7  37.3  18.500  28.030735    07-2014
# ...

# %%
df_merged.groupby("year").agg({
    "TEMP" : ['max', 'min', 'mean'],
})
# Out:
#       TEMP
#        max     min       mean
# year
# 2013  38.0 -11.600  15.690783
# 2014  41.6 -14.500  13.915571
# 2015  39.3 -13.800  13.414439
# 2016  38.2 -19.900  13.582987
# 2017  16.2 -13.425   0.366012

# %%
dongsi = df_merged[(df_merged["station"] == "Dongsi") & (df_merged["year"] == 2014)]

quest_2 = dongsi.groupby(["month","year"]).agg(
    max =('TEMP','max'),
    min = ('TEMP','min'),
    mean = ('TEMP','mean'),
).reset_index()

quest_2
# Out:
#     month  year   max   min       mean
# 0       1  2014  11.4  -9.9  -0.205914
# 1       2  2014   9.0 -11.5  -0.416220
# 2       3  2014  25.7  -5.6   9.859140
# 3       4  2014  29.5   4.6  17.042500
# 4       5  2014  41.1   5.6  21.778495
# 5       6  2014  35.5  14.6  24.703750
# 6       7  2014  36.2  21.0  28.170833
# 7       8  2014  34.7  16.9  26.047043
# 8       9  2014  33.6  10.8  20.814028
# 9      10  2014  23.9   2.2  13.442070
# 10     11  2014  19.0  -4.0   5.528333
# 11     12  2014  11.0 -11.0  -1.168548

# %% [markdown]
# ### Explore Korelasi

# %%
corr = df_merged.select_dtypes("float64").corr()
corr
# Out:
#           PM2.5      PM10       SO2       NO2        CO        O3      TEMP  \
# PM2.5  1.000000  0.675712  0.332772  0.335999  0.517557 -0.108585  0.048161
# PM10   0.675712  1.000000  0.207138  0.352694  0.385134 -0.042690  0.097815
# SO2    0.332772  0.207138  1.000000  0.233038  0.360554 -0.189423 -0.327772
# NO2    0.335999  0.352694  0.233038  1.000000  0.402586 -0.317307 -0.127565
# CO     0.517557  0.385134  0.360554  0.402586  1.000000 -0.247121 -0.103802
# O3    -0.108585 -0.042690 -0.189423 -0.317307 -0.247121  1.000000  0.511495
# TEMP   0.048161  0.097815 -0.327772 -0.127565 -0.103802  0.511495  1.000000
# PRES  -0.103166 -0.127743  0.231815  0.096860  0.048032 -0.386915 -0.813312
# DEWP   0.229494  0.185118 -0.279725  0.037688  0.109293  0.234957  0.820247
# RAIN  -0.003381 -0.016519 -0.043454 -0.028518  0.005909  0.034711  0.037647
# WSPM  -0.240749 -0.146943 -0.107371 -0.299496 -0.282525  0.296345  0.032601
#
#            PRES      DEWP      RAIN      WSPM
# ...

# %% [markdown]
# **Insight:**
# - Terlihat kondisi suhu rata-rata bulanan ke-12 station mencapai maksimum pada 2014 dan minimum pada tahun 2016
# - perkembangan suhu station dongsi pada tahun 2014, terlihat suhu mencapai titik maksimum pada pertengah tahun dan mencapai titik minimum pada akhir-awal tahun
# - salah satu hubungan yang terlihat adalah antara suhu dan O3 memiliki korelasi sedang positif 0.511 artinya disaat suhu meningkat kadar O3 juga meningkat

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# Kapan kondisi rata-rata suhu bulanan ke 12 station mencapai batas maksimum dan minimum dalam kurun 2013-2017 ?

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))
 
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
 
sns.barplot(x="month_year", y='max', data=quest_1.sort_values(by='max',ascending=False).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel("Rata-Rata Suhu")
ax[0].set_xlabel("waktu")
ax[0].set_title("Nilai Maksimum", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)
 
sns.barplot(x="month_year", y='min', data=quest_1.sort_values(by='min', ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel("Rata-Rata Suhu")
ax[1].set_xlabel("waktu")
ax[1].invert_yaxis()
# ax[1].yaxis.set_label_position("right")
# ax[1].yaxis.tick_right()
ax[1].set_title("Nilai Maksimum", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)
 
plt.suptitle("Nilai Maksimum dan Minimum Rata-Rata Suhu Bulanan (12 Station di RRT)", fontsize=20)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9204\2567932450.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="month_year", y='max', data=quest_1.sort_values(by='max',ascending=False).head(5), palette=colors, ax=ax[0])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9204\2567932450.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="month_year", y='min', data=quest_1.sort_values(by='min', ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# Bagaimana perkembangan suhu bulanan di wilayah Dongsi pada bulan tahun 2014 ?

# %%
quest_2
quest_2['month_year'] = quest_2['month'].astype(str).str.zfill(2) + '-' + quest_2['year'].astype(str).str.zfill(2)
quest_2
# Out:
#     month  year   max   min       mean month_year
# 0       1  2014  11.4  -9.9  -0.205914    01-2014
# 1       2  2014   9.0 -11.5  -0.416220    02-2014
# 2       3  2014  25.7  -5.6   9.859140    03-2014
# 3       4  2014  29.5   4.6  17.042500    04-2014
# 4       5  2014  41.1   5.6  21.778495    05-2014
# 5       6  2014  35.5  14.6  24.703750    06-2014
# 6       7  2014  36.2  21.0  28.170833    07-2014
# 7       8  2014  34.7  16.9  26.047043    08-2014
# 8       9  2014  33.6  10.8  20.814028    09-2014
# 9      10  2014  23.9   2.2  13.442070    10-2014
# 10     11  2014  19.0  -4.0   5.528333    11-2014
# 11     12  2014  11.0 -11.0  -1.168548    12-2014

# %%
quest_2['nama_bulan'] = pd.to_datetime(quest_2['month_year'])
quest_2['nama_bulan'] = quest_2['nama_bulan'].dt.strftime('%B')
# quest_2['nama_bulan']

plt.figure(figsize=(10, 5)) 
plt.plot(quest_2['nama_bulan'], quest_2['mean'], marker='o', linewidth=2, color="#72BCD4") 
plt.title("Perkembangan Rata-rata Suhu Bulanan di Station Dongsi (2014)", loc="center", fontsize=14) 
plt.xticks(fontsize=10,rotation=45) 
plt.yticks(fontsize=10)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9204\274710908.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   quest_2['nama_bulan'] = pd.to_datetime(quest_2['month_year'])

# %% [markdown]
# ### Pertanyaan 3

# %% [markdown]
# Apakah ada hubungan antara suhu dan kadar O3, NO2, SO2 di udara?

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1, cbar=True)
plt.title('Matriks Korelasi Antar Variabel')
plt.xticks(size=8)
plt.yticks(size=8,rotation=360)
plt.show()

# %% [markdown]
# ## Analisis Lanjutan (Opsional) -  Clustering Station Berdasarkan POLUTAN

# %%
cluster = df_merged.groupby("station").agg({
    "PM2.5":'mean',
    "PM10" : 'mean',
    "SO2" : 'mean',
    "NO2" : 'mean',
    "CO" : 'mean',
    "O3" : 'mean',
}).reset_index()

cluster
# Out:
#           station      PM2.5       PM10        SO2        NO2           CO  \
# 0    Aotizhongxin  60.193907  72.199625  15.780740  43.143647   926.951261
# 1       Changping  54.692313  68.894299  13.686789  38.125550   892.899463
# 2        Dingling  51.305733  62.999862  11.522979  24.901491   790.270360
# 3          Dongsi  60.455077  71.762322  16.841742  42.007490  1014.057904
# 4        Guanyuan  60.977350  74.191392  15.840364  43.724011   953.771058
# 5         Gucheng  61.003288  76.303462  14.395762  42.070475   973.339206
# 6         Huairou  54.679403  66.255763  11.529430  29.570204   894.217685
# 7    Nongzhanguan  59.456721  71.614955  16.660722  42.736213   967.170366
# 8          Shunyi  58.194394  68.768728  12.629685  37.634213   920.632157
# 9         Tiantan  60.135720  73.647119  13.360132  43.193707   985.626948
# 10         Wanliu  60.580228  73.454322  16.835093  45.628160   945.561008
# ...

# %% [markdown]
# Untuk melakukan clustering, saya akan membaginya berdasarkan polutan seperti tabel dibawah, adapun cara saya melakukannya:
# - Memberi peringkat wilayah untuk setiap polutan
# - Pemeringkatan secara ascending, dimana berdasarkan informasi di media polutan diatas cenderung bersifat buruk. Kecuali untuk OZON (O3)
# - Hasil perangkingan dijumlahkan, dan di ranking secara descending untuk menentukan kluster
# - Stasion akan dibagi menjadi 3 kluster yakni Tinggi, Menengah, Rendah. Berdasarkan Jumlah peringkat
# - Disclaimer, perangkingan bersifat relatif hanya pada 12 stasion pada tabel

# %%
# Mebuat Perankingan
cluster['rank_PM2.5'] = cluster['PM2.5'].rank(ascending=False)
cluster['rank_PM10'] = cluster['PM10'].rank(ascending=False)
cluster['rank_SO2'] = cluster['SO2'].rank(ascending=False)
cluster['rank_NO2'] = cluster['NO2'].rank(ascending=False)
cluster['rank_CO'] = cluster['CO'].rank(ascending=False)
cluster['rank_O3'] = cluster['O3'].rank(ascending=True)
cluster['sum_rank'] = cluster[['PM10','PM2.5','NO2','SO2','CO']].rank(ascending=False).sum(axis=1)
cluster['sum_rank'] = cluster['sum_rank']+cluster['rank_O3']
cluster['final_rank'] = cluster['sum_rank'].rank(ascending=True)
cluster['final_rank'] = pd.to_numeric(cluster['final_rank'])
cluster
# Out:
#           station      PM2.5       PM10        SO2        NO2           CO  \
# 0    Aotizhongxin  60.193907  72.199625  15.780740  43.143647   926.951261
# 1       Changping  54.692313  68.894299  13.686789  38.125550   892.899463
# 2        Dingling  51.305733  62.999862  11.522979  24.901491   790.270360
# 3          Dongsi  60.455077  71.762322  16.841742  42.007490  1014.057904
# 4        Guanyuan  60.977350  74.191392  15.840364  43.724011   953.771058
# 5         Gucheng  61.003288  76.303462  14.395762  42.070475   973.339206
# 6         Huairou  54.679403  66.255763  11.529430  29.570204   894.217685
# 7    Nongzhanguan  59.456721  71.614955  16.660722  42.736213   967.170366
# 8          Shunyi  58.194394  68.768728  12.629685  37.634213   920.632157
# 9         Tiantan  60.135720  73.647119  13.360132  43.193707   985.626948
# 10         Wanliu  60.580228  73.454322  16.835093  45.628160   945.561008
# ...

# %%
#Kategorisasi

for index,data in cluster.iterrows() :
    if   data['final_rank'] < 5 :
         cluster.at[index,'kluster'] = "Rendah"
    elif data['final_rank'] > 8 :
         cluster.at[index,'kluster'] = "Tinggi"
    else : 
         cluster.at[index,'kluster'] = "Menengah"
  
cluster
# Out:
#           station      PM2.5       PM10        SO2        NO2           CO  \
# 0    Aotizhongxin  60.193907  72.199625  15.780740  43.143647   926.951261
# 1       Changping  54.692313  68.894299  13.686789  38.125550   892.899463
# 2        Dingling  51.305733  62.999862  11.522979  24.901491   790.270360
# 3          Dongsi  60.455077  71.762322  16.841742  42.007490  1014.057904
# 4        Guanyuan  60.977350  74.191392  15.840364  43.724011   953.771058
# 5         Gucheng  61.003288  76.303462  14.395762  42.070475   973.339206
# 6         Huairou  54.679403  66.255763  11.529430  29.570204   894.217685
# 7    Nongzhanguan  59.456721  71.614955  16.660722  42.736213   967.170366
# 8          Shunyi  58.194394  68.768728  12.629685  37.634213   920.632157
# 9         Tiantan  60.135720  73.647119  13.360132  43.193707   985.626948
# 10         Wanliu  60.580228  73.454322  16.835093  45.628160   945.561008
# ...

# %%
# Visualisasi

colors = ["#D32F2F", "#D32F2F", "#D32F2F", "#D32F2F", "#FFEB3B", "#FFEB3B", "#FFEB3B", "#FFEB3B", "#81C784", "#81C784", "#81C784", "#81C784"]
 
sns.barplot(x="sum_rank", y='station',orient='h' ,data=cluster.sort_values(by='final_rank',ascending=False), palette=colors)
plt.title("Klusterisasi Polutan di 13 Stasiun di RRT", loc="center", fontsize=15)
plt.tick_params(axis ='y', labelsize=12)
plt.legend(['Tinggi (Buruk)', 'Medium (Agak Buruk)', 'Rendah (Baik)'], loc='lower right')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9204\489872455.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sum_rank", y='station',orient='h' ,data=cluster.sort_values(by='final_rank',ascending=False), palette=colors)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **Answer :**
# 1. Rata-rata bulanan suhu di 12 Station pada rentang 2013-2017 mencapai titik maksimum pada **Bulan Mei 2014** dan titik minimum pada **Januari 2016**
# 2. Perkembangan suhu di station dongsi pada tahun 2014 menunjukkan pola yang memiliki puncak suhu Maksimum pada pertengah tahun (Juli) dan suhu minimum pada akhir dan awal tahun (Desemeber dan Januari)
# 3. Suhu memiliki korelasi yang sedang dengan arah positif dengan O3, sedangkan Suhu dengan NO2 dan CO2 memiliki korelasi negatif yang cukup lemah
# 4. **Dingling** merupakan wilayah paling banyak polutan di banding 11 station yang lain

# %%
df_merged.to_csv("df_merged.csv", index=False)
